# %% [markdown]
# #### 1.  Write a program to print your name, college name and course using: a) Single line comment b) Multi-line comment (using #) c) Docstring

# %%
#This program print student details 
print("Name :Yash Wakode")
print("College name : KDK college")
print("Course : B.Tech in CSE")
# Out:
# Name :Yash Wakode
# College name : KDK college
# Course : B.Tech in CSE

# %%
# This program prints student details
# Name: Yash Wakode
# College: KDK College of Engineering
# Course: B.Tech CSE

print("Name : Yash Wakode")
print("College name : KDK College of Engineering")
print("Course : B.Tech in CSE")
# Out:
# Name : Yash Wakode
# College name : KDK College of Engineering
# Course : B.Tech in CSE

# %%
"""
This program prints student details.
Name: Yash Wakode
College: ABC College
Course: B.Tech CSE
"""

print("Name : Yash Wakode")
print("College name : KDK College of Engineering")
print("Course : B.Tech in CSE")
# Out:
# Name : Yash Wakode
# College name : KDK College of Engineering
# Course : B.Tech in CSE

# %% [markdown]
# ####  2. Correct the indentation in the following code:if True:
# #### print("Hello World")
# #### print("Welcome to Python")

# %%
print("Hello World")
print("Welcome to Python")
# Out:
# Hello World
# Welcome to Python

# %% [markdown]
# #### 3. Create variables for: name (string), age (integer), height (float), is_student (boolean).Print all variables with their data types using type()

# %%
name="Yash Wakode"
age=22
height=5.8
is_student=True

print("Name :",name,type(name))
print("Age :",age,type(age))
print("Height :",height,type(height))
print("Is_Student :",is_student,type(is_student))
# Out:
# Name : Yash Wakode <class 'str'>
# Age : 22 <class 'int'>
# Height : 5.8 <class 'float'>
# Is_Student : True <class 'bool'>

# %% [markdown]
# ####  4. Take two numbers from user and print: Sum, Difference, Product, Division, Floor Division, Modulus, Power

# %%
num1=float(input("Enter first number"))
num2=float(input("Enter second number"))

print("Sum :",num1+num2)
print("Difference :",num1-num2)
print("Product :",num1*num2)
print("Division :",num1/num2)
print("Floor Division :",num1//num2)
print("Modulus :",num1%num2)
print("Power :",num1**num2)
# Out:
# Enter first number 10
# Enter second number 4
# Sum : 14.0
# Difference : 6.0
# Product : 40.0
# Division : 2.5
# Floor Division : 2.0
# Modulus : 2.0
# Power : 10000.0

# %% [markdown]
# #### 5. Take two numbers and check: Equal, Not Equal, Greater, Smaller, Greater or Equal, Smaller or Equal

# %%
num1=float(input("Enter first number"))
num2=float(input("Enter second number"))

print("Equal :",num1==num2)
print("Not Equal :",num1!=num2)
print("Greater :",num1>num2)
print("Smaller :",num1<num2)
print("Greater or Equal :",num1>=num2)
print("Smaller or Equal :",num1<=num2)
# Out:
# Enter first number 14
# Enter second number 12
# Equal : False
# Not Equal : True
# Greater : True
# Smaller : False
# Greater or Equal : True
# Smaller or Equal : False
