# %% [markdown]
# #### 1. Class Name: Shape
# #### Problem
# #### Create an abstract class named Shape.
# #### Explanation
# #### A shape can have different formulas for area and perimeter. Therefore, create two abstract
# #### methods:
# #### • area()
# #### • perimeter()
# #### Create subclasses like Circle and Rectangle and implement both methods.

# %%
from abc import ABC, abstractmethod
class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

    @abstractmethod
    def perimeter(self):
        pass

class Circle(Shape):
    def __init__(self,radius):
        self.radius=radius

    def area(self):
        return 3.14*self.radius*self.radius

    def perimeter(self):
        return 2 * 3.14*self.radius

class Rectangle(Shape):
    def __init__(self,length,width):
        self.length=length
        self.width=width

    def area(self):
        return self.length*self.width

    def perimeter(self):
        return 2*(self.length+self.width)

c=Circle(5)
print("Circle Area :",c.area())
print("Circle Perimeter :",c.perimeter())

r=Rectangle(10,5)
print("Rectangle Area :",r.area())
print("Rectangle Perimeter :",r.perimeter())
# Out:
# Circle Area : 78.5
# Circle Perimeter : 31.400000000000002
# Rectangle Area : 50
# Rectangle Perimeter : 30

# %% [markdown]
# ####  2. Class Name: Vehicle
# ####  Problem
# ####  Create an abstract class named Vehicle.
# ####  Explanation
# ####  Every vehicle can start and stop, but each vehicle does it differently.
# ####  Create two abstract methods:
# ####  • start()
# ####  • stop()
# ####  Create a Car class that implements both methods.

# %%
from abc import ABC, abstractmethod
class Vehicle(ABC):
    @abstractmethod
    def start(self):
        pass

    @abstractmethod
    def stop(self):
        pass

class Car(Vehicle):

    def start(self):
        print("Car started using the start button.")

    def stop(self):
        print("Car stopped by applying the brakes.")

c = Car()

c.start()
c.stop()
# Out:
# Car started using the start button.
# Car stopped by applying the brakes.

# %% [markdown]
# ####  3. Class Name: Animal
# #### Problem
# #### Create an abstract class named Animal.
# #### Explanation
# #### Every animal makes a sound, but the sound depends on the animal.
# #### Create an abstract method:
# #### • make_sound()
# #### Create subclasses:
# #### • Dog
# #### • Cat
# #### Each should implement its own sound.

# %%
from abc import ABC, abstractmethod

class Animal(ABC):

    @abstractmethod
    def make_sound(self):
        pass

class Dog(Animal):

    def make_sound(self):
        print("Dog says: Bark")

class Cat(Animal):

    def make_sound(self):
        print("Cat says: Meow")

dog = Dog()
cat = Cat()

dog.make_sound()
cat.make_sound()
# Out:
# Dog says: Bark
# Cat says: Meow

# %% [markdown]
# ####   4. Class Name: Payment
# #### Problem
# #### Create an abstract class named Payment.
# #### Explanation
# #### Every payment processes money differently.
# #### Create an abstract method:
# #### • process_payment(amount)
# #### Create subclasses:
# #### • CreditCard
# #### • Cash
# #### Each should process the payment in its own way.

# %%
from abc import ABC, abstractmethod

class Payment(ABC):

    @abstractmethod
    def process_payment(self, amount):
        pass

class CreditCard(Payment):

    def process_payment(self, amount):
        print(f"Credit Card Payment of ₹{amount} processed successfully.")

class Cash(Payment):

    def process_payment(self, amount):
        print(f"Cash Payment of ₹{amount} received successfully.")

card = CreditCard()
cash = Cash()

card.process_payment(10000)
cash.process_payment(2500)
# Out:
# Credit Card Payment of ₹10000 processed successfully.
# Cash Payment of ₹2500 received successfully.

# %% [markdown]
# ####  5. Class Name: Report
# ####  Problem
# ####  Create an abstract class named Report.
# ####  Explanation
# ####  Different report formats generate reports differently.
# ####  Create an abstract method:
# ####  • generate()
# ####  Create:
# ####  • PDFReport
# ####  • ExcelReport
# ####  Each should generate the report differently.

# %%
from abc import ABC, abstractmethod
class Report(ABC):

    @abstractmethod
    def generate(self):
        pass

class PDFReport(Report):

    def generate(self):
        print("Generating PDF Report...")

class ExcelReport(Report):

    def generate(self):
        print("Generating Excel Report...")

pdf = PDFReport()
excel = ExcelReport()

pdf.generate()
excel.generate()
# Out:
# Generating PDF Report...
# Generating Excel Report...

# %% [markdown]
# #### 6. Class Name: BankAccount
# #### Problem
# #### Create an abstract class named BankAccount.
# #### Explanation
# #### Different bank accounts calculate interest differently.
# #### Create an abstract method:
# #### • calculate_interest()
# #### Create:
# #### • SavingsAccount
# #### Implement the interest calculation.

# %%
from abc import ABC, abstractmethod

class BankAccount(ABC):

    @abstractmethod
    def calculate_interest(self):
        pass

class SavingsAccount(BankAccount):

    def __init__(self, balance):
        self.balance = balance

    def calculate_interest(self):
        interest = self.balance * 0.05   
        print("Interest:", interest)
        
account = SavingsAccount(100000)

account.calculate_interest()
# Out:
# Interest: 5000.0

# %% [markdown]
# #### 7. Class Name: Device
# #### Problem
# #### Create an abstract class named Device.
# #### Explanation
# #### Every electronic device can be turned on and off.
# #### Create abstract methods:
# #### • turn_on()
# #### • turn_off()
# #### Implement them in a subclass such as Laptop or TV.

# %%
from abc import ABC, abstractmethod
class Device(ABC):

    @abstractmethod
    def turn_on(self):
        pass

    @abstractmethod
    def turn_off(self):
        pass

class Laptop(Device):

    def turn_on(self):
        print("Laptop is turning on...")

    def turn_off(self):
        print("Laptop is shutting down...")

laptop = Laptop()

laptop.turn_on()
laptop.turn_off()
# Out:
# Laptop is turning on...
# Laptop is shutting down...

# %% [markdown]
# #### 8. Class Name: Employee
# #### Problem
# #### Create an abstract class named Employee.
# #### Explanation
# #### Employees receive bonuses based on their roles.
# #### Create an abstract method:
# #### • calculate_bonus()
# #### Create subclass:
# #### • Manager
# #### Implement the bonus calculation.

# %%
from abc import ABC, abstractmethod

class Employee(ABC):

    @abstractmethod
    def calculate_bonus(self):
        pass

class Manager(Employee):

    def __init__(self, salary):
        self.salary = salary

    def calculate_bonus(self):
        bonus = self.salary * 0.20   
        print("Manager Bonus:", bonus)

manager = Manager(50000)

manager.calculate_bonus()
# Out:
# Manager Bonus: 10000.0

# %% [markdown]
# #### 9. Class Name: Transport
# #### Problem
# #### Create an abstract class named Transport.
# #### Explanation
# #### Every transport moves differently and uses different fuel.
# #### Create abstract methods:
# #### • move()
# #### • fuel_type()
# #### Create subclasses like:
# #### • Car
# #### • Train

# %%
from abc import ABC, abstractmethod

class Transport:

    @abstractmethod
    def move(self):
        pass

    @abstractmethod
    def fuel_type(self):
        pass

class Car(Transport):
    def move(self):
        print("Car moves on roads")

    def fuel_type(self):
        print("Fuel Type : Petrol/Diesel")

class Train(Transport):
    def move(self):
        print("Trains moves on railway track")

    def fuel_type(self):
        print("Fuel Type : Electricity/Diesel")

car=Car()
train=Train()

car.move()
car.fuel_type()
print("-----"*8)
train.move()
train.fuel_type()
# Out:
# Car moves on roads
# Fuel Type : Petrol/Diesel
# ----------------------------------------
# Trains moves on railway track
# Fuel Type : Electricity/Diesel

# %% [markdown]
# #### 10. Class Name: Notification
# #### Problem
# #### Create an abstract class named Notification.
# #### Explanation
# #### Notifications can be sent in different ways.
# #### Create abstract method:
# #### • send(message)
# #### Create subclasses:
# #### • EmailNotification
# #### • SMSNotification

# %%
from abc import ABC, abstractmethod

class Notification(ABC):

    @abstractmethod
    def send(self, message):
        pass

class EmailNotification(Notification):

    def send(self, message):
        print("Email Sent:", message)

class SMSNotification(Notification):

    def send(self, message):
        print("SMS Sent:", message)

email = EmailNotification()
sms = SMSNotification()

email.send("Welcome to our website!")
sms.send("Your OTP is 123456")
# Out:
# Email Sent: Welcome to our website!
# SMS Sent: Your OTP is 123456

# %% [markdown]
# #### 11. Class Name: FileHandler
# #### Problem
# #### Create an abstract class named FileHandler.
# #### Explanation
# #### Files can be read and written differently.
# #### Create abstract methods:
# #### • read()
# #### • write(data)
# #### Create subclasses like:
# #### • TextFileHandler
# #### • CSVFileHandler

# %%
from abc import ABC, abstractmethod

class FileHandler(ABC):

    @abstractmethod
    def read(self):
        pass

    @abstractmethod
    def write(self, data):
        pass

class TextFileHandler(FileHandler):

    def read(self):
        print("Reading data from a text file.")

    def write(self, data):
        print("Writing to text file:", data)

class CSVFileHandler(FileHandler):

    def read(self):
        print("Reading data from a CSV file.")

    def write(self, data):
        print("Writing to CSV file:", data)

text = TextFileHandler()
csv = CSVFileHandler()

text.read()
text.write("Hello World")

print("------"*8)

csv.read()
csv.write("Name,Age\nYash,22")
# Out:
# Reading data from a text file.
# Writing to text file: Hello World
# ------------------------------------------------
# Reading data from a CSV file.
# Writing to CSV file: Name,Age
# Yash,22

# %% [markdown]
# #### 12. Class Name: GameCharacter
# #### Problem
# #### Create an abstract class named GameCharacter.
# #### Explanation
# #### Every game character attacks differently.
# #### Create abstract method:
# #### • attack()
# #### Create subclasses:
# #### • Warrior
# #### • Mage

# %%
from abc import ABC, abstractmethod

class GameCharacter(ABC):

    @abstractmethod
    def attack(self):
        pass

class Warrior(GameCharacter):
    def attack(self):
        print("Warrior attacks with a sword")

class Mage(GameCharacter):
    def attack(self):
        print("Mage attacks with a magic spell")
warrior=Warrior()
mage=Mage()

warrior.attack()

mage.attack()
# Out:
# Warrior attacks with a sword
# Mage attacks with a magic spell

# %% [markdown]
# #### 13. Class Name: Calculator
# #### Problem
# #### Create an abstract class named Calculator.
# #### Explanation
# #### Different calculators perform different operations.
# #### Create abstract method:
# #### • compute(a, b)
# #### Create subclasses:
# #### • AdditionCalculator
# #### • MultiplicationCalculator

# %%
from abc import ABC, abstractmethod
class Calculator:
    @abstractmethod
    def compute(self,a,b):
        pass

class AdditionCalculator(Calculator):
    def compute(self,a,b):
        return a+b

class MultiplicationCalculator(Calculator):
    def compute(self,a,b):
        return a*b

add=AdditionCalculator()
mul=MultiplicationCalculator()

print("Addition :",add.compute(10,5))
print("Multiplication :",mul.compute(10,4))
# Out:
# Addition : 15
# Multiplication : 40

# %% [markdown]
# #### 14. Class Name: Database
# #### Problem
# #### Create an abstract class named Database.
# #### Explanation
# #### Different databases connect and execute queries differently.
# #### Create abstract methods:
# #### • connect()
# #### • query(sql)
# #### Create subclasses:
# #### • MySQLDatabase
# #### • MongoDatabase

# %%
from abc import ABC, abstractmethod

class Database(ABC):

    @abstractmethod
    def connect(self):
        pass

    @abstractmethod
    def query(self, sql):
        pass

class MySQLDatabase(Database):

    def connect(self):
        print("Connected to MySQL Database.")

    def query(self, sql):
        print("Executing MySQL Query:", sql)

class MongoDatabase(Database):

    def connect(self):
        print("Connected to MongoDB Database.")

    def query(self, sql):
        print("Executing MongoDB Query:", sql)

mysql = MySQLDatabase()
mongo = MongoDatabase()

mysql.connect()
mysql.query("SELECT * FROM students")
print("------"*8)
mongo.connect()
mongo.query("{name: 'Yash'}")
# Out:
# Connected to MySQL Database.
# Executing MySQL Query: SELECT * FROM students
# ------------------------------------------------
# Connected to MongoDB Database.
# Executing MongoDB Query: {name: 'Yash'}

# %% [markdown]
# #### 15. Class Name: Shape3D
# #### Problem
# #### Create an abstract class named Shape3D.
# #### Explanation
# #### Three-dimensional shapes have different formulas.
# #### Create abstract methods:
# #### • volume()
# #### • surface_area()
# #### Create subclasses:
# #### • Cube
# #### • Sphere

# %%
from abc import ABC, abstractmethod

class Shape3D(ABC):

    @abstractmethod
    def volume(self):
        pass

    @abstractmethod
    def surface_area(self):
        pass

class Cube(Shape3D):

    def __init__(self, side):
        self.side = side

    def volume(self):
        return self.side ** 3

    def surface_area(self):
        return 6 * (self.side ** 2)

class Sphere(Shape3D):

    def __init__(self, radius):
        self.radius = radius

    def volume(self):
        return (4 / 3) * 3.14 * (self.radius ** 3)

    def surface_area(self):
        return 4 * 3.14 * (self.radius ** 2)

cube = Cube(4)
sphere = Sphere(3)

print("Cube Volume:", cube.volume())
print("Cube Surface Area:", cube.surface_area())
print("-------"*8)
print("Sphere Volume:", sphere.volume())
print("Sphere Surface Area:", sphere.surface_area())
# Out:
# Cube Volume: 64
# Cube Surface Area: 96
# --------------------------------------------------------
# Sphere Volume: 113.03999999999999
# Sphere Surface Area: 113.04

# %% [markdown]
# #  Abstraction Using super()

# %% [markdown]
# #### 16. Class Name: Shape
# #### Problem
# #### Create an abstract class named Shape.
# #### Explanation
# #### The constructor should accept a shape's color.
# #### __init__(self, color)
# #### Create an abstract method:
# #### • area()
# #### Create subclass:
# #### • Circle
# #### Use super() to initialize the color.

# %%
from abc import ABC, abstractmethod

class Shape(ABC):
    def __init__(self, color):
        self.color = color

    @abstractmethod
    def area(self):
        pass

class Circle(Shape):
    def __init__(self, color, radius):
        super().__init__(color)  
        self.radius = radius

    def area(self):
        return 3.14 * self.radius * self.radius

c1 = Circle("Red", 4)

print("Color:", c1.color)
print("Area:", c1.area())
# Out:
# Color: Red
# Area: 50.24

# %% [markdown]
# #### 17. Class Name: Vehicle
# #### Problem
# #### Create an abstract class named Vehicle.
# #### Explanation
# #### Store the vehicle brand in the constructor.
# #### __init__(self, brand)
# #### Create abstract methods:
# #### • start()
# #### • stop()
# #### Create subclass:
# #### • Car
# #### Use super() to initialize the brand.

# %%
from abc import ABC, abstractmethod

class Vehicle(ABC):
    def __init__(self, brand):
        self.brand = brand

    @abstractmethod
    def start(self):
        pass

    @abstractmethod
    def stop(self):
        pass

class Car(Vehicle):
    def __init__(self, brand, model):
        super().__init__(brand)   
        self.model = model

    def start(self):
        print(f"{self.brand} {self.model} is starting.")

    def stop(self):
        print(f"{self.brand} {self.model} is stopping.")

c1 = Car("Toyota", "Fortuner")

print("Brand:", c1.brand)
print("Model:", c1.model)

c1.start()
c1.stop()
# Out:
# Brand: Toyota
# Model: Fortuner
# Toyota Fortuner is starting.
# Toyota Fortuner is stopping.

# %% [markdown]
# #### 18. Class Name: Animal
# #### Problem
# #### Create an abstract class named Animal.
# #### Explanation
# #### Store the animal's name in the constructor.
# #### __init__(self, name)
# #### Create abstract method:
# #### • make_sound()
# #### Create subclass:
# #### • Dog
# #### Use super() to initialize the name.

# %%
from abc import ABC, abstractmethod

class Animal(ABC):
    def __init__(self, name):
        self.name = name

    @abstractmethod
    def make_sound(self):
        pass

class Dog(Animal):
    def __init__(self, name, breed):
        super().__init__(name)    
        self.breed = breed

    def make_sound(self):
        print(f"{self.name} says: Woof! Woof!")

d1 = Dog("Captain", "Labrador")

print("Name:", d1.name)
print("Breed:", d1.breed)

d1.make_sound()
# Out:
# Name: Captain
# Breed: Labrador
# Captain says: Woof! Woof!

# %% [markdown]
# #### 19. Class Name: Payment
# #### Problem
# #### Create an abstract class named Payment.
# #### Explanation
# #### Store the payment amount in the constructor.
# #### __init__(self, amount)
# #### Create abstract method:
# #### • process_payment()
# #### Create subclasses:
# #### • CreditCard
# #### • Cash
# #### Use super() to initialize the amount.

# %%
from abc import ABC, abstractmethod

class Payment(ABC):
    def __init__(self, amount):
        self.amount = amount

    @abstractmethod
    def process_payment(self):
        pass

class CreditCard(Payment):
    def __init__(self, amount, card_number):
        super().__init__(amount)
        self.card_number = card_number

    def process_payment(self):
        print(f"Credit Card Payment of ₹{self.amount} processed.")

class Cash(Payment):
    def __init__(self, amount):
        super().__init__(amount)      
        
    def process_payment(self):
        print(f"Cash Payment of ₹{self.amount} received.")

cc = CreditCard(8000, "1234-5678-9012")
cash = Cash(1500)

cc.process_payment()
cash.process_payment()
# Out:
# Credit Card Payment of ₹8000 processed.
# Cash Payment of ₹1500 received.

# %% [markdown]
# #### 20. Class Name: Employee
# #### Problem
# #### Create an abstract class named Employee.
# #### Explanation
# #### Store the employee name.
# #### __init__(self, name)
# #### Create abstract method:
# #### • calculate_bonus()
# #### Create subclass:
# #### • Manager
# #### Use super() to initialize the name.

# %%
from abc import ABC, abstractmethod

class Employee(ABC):
    def __init__(self, name):
        self.name = name

    @abstractmethod
    def calculate_bonus(self):
        pass

class Manager(Employee):
    def __init__(self, name, salary):
        super().__init__(name)     
        self.salary = salary

    def calculate_bonus(self):
        bonus = self.salary * 0.20   
        return bonus

m1 = Manager("Roshan", 70000)

print("Employee Name:", m1.name)
print("Salary:", m1.salary)
print("Bonus:", m1.calculate_bonus())
# Out:
# Employee Name: Roshan
# Salary: 70000
# Bonus: 14000.0

# %% [markdown]
# #### 21. Class Name: Report
# #### Problem
# #### Create an abstract class named Report.
# #### Explanation
# #### Store the report title.
# #### __init__(self, title)
# #### Create abstract method:
# #### • generate()
# #### Create subclass:
# #### • PDFReport
# #### Use super() to initialize the title.

# %%
from abc import ABC, abstractmethod

class Report(ABC):
    def __init__(self, title):
        self.title = title

    @abstractmethod
    def generate(self):
        pass

class PDFReport(Report):
    def __init__(self, title, author):
        super().__init__(title)      
        self.author = author

    def generate(self):
        print(f"Generating PDF Report: {self.title}")
        print(f"Author: {self.author}")

r1 = PDFReport("Annual Sales Report", "Rohit")

print("Title:", r1.title)
print("Author:", r1.author)

r1.generate()
# Out:
# Title: Annual Sales Report
# Author: Rohit
# Generating PDF Report: Annual Sales Report
# Author: Rohit

# %% [markdown]
# #### 22. Class Name: BankAccount
# #### Problem
# #### Create an abstract class named BankAccount.
# #### Explanation
# #### Store the account balance.
# #### __init__(self, balance)
# #### Create abstract method:
# #### • calculate_interest()
# #### Create subclass:
# #### • SavingsAccount
# #### Use super() to initialize the balance.

# %%
from abc import ABC, abstractmethod

class BankAccount(ABC):
    def __init__(self, balance):
        self.balance = balance

    @abstractmethod
    def calculate_interest(self):
        pass

class SavingsAccount(BankAccount):
    def __init__(self, balance, rate):
        super().__init__(balance)      
        self.rate = rate

    def calculate_interest(self):
        interest = (self.balance * self.rate) / 100
        return interest

s1 = SavingsAccount(60000, 5)

print("Balance:", s1.balance)
print("Interest Rate:", s1.rate, "%")
print("Interest:", s1.calculate_interest())
# Out:
# Balance: 60000
# Interest Rate: 5 %
# Interest: 3000.0

# %% [markdown]
# #### 23. Class Name: Device
# #### Problem
# #### Create an abstract class named Device.
# #### Explanation
# #### Store the device brand.
# #### __init__(self, brand)
# #### Create abstract methods:
# #### • turn_on()
# #### • turn_off()
# #### Create subclass:
# #### • Laptop
# #### Use super() to initialize the brand.

# %%
from abc import ABC, abstractmethod

class Device(ABC):
    def __init__(self, brand):
        self.brand = brand

    @abstractmethod
    def turn_on(self):
        pass

    @abstractmethod
    def turn_off(self):
        pass

class Laptop(Device):
    def __init__(self, brand, model):
        super().__init__(brand)     
        self.model = model

    def turn_on(self):
        print(f"{self.brand} {self.model} is turning on.")

    def turn_off(self):
        print(f"{self.brand} {self.model} is turning off.")

l1 = Laptop("Asus", "Expertbook")

print("Brand:", l1.brand)
print("Model:", l1.model)

l1.turn_on()
l1.turn_off()
# Out:
# Brand: Asus
# Model: Expertbook
# Asus Expertbook is turning on.
# Asus Expertbook is turning off.

# %% [markdown]
# #### 24. Class Name: Transport
# ####  Problem
# ####  Create an abstract class named Transport.
# ####  Explanation
# ####  Store the transport speed.
# ####  __init__(self, speed)
# ####  Create abstract methods:
# ####  • move()
# ####  • fuel_type()
# ####  Create subclass:
# ####  • Car
# ####  Use super() to initialize the speed.

# %%
from abc import ABC, abstractmethod

class Transport(ABC):
    def __init__(self, speed):
        self.speed = speed

    @abstractmethod
    def move(self):
        pass

    @abstractmethod
    def fuel_type(self):
        pass

class Car(Transport):
    def __init__(self, speed, brand):
        super().__init__(speed)      
        self.brand = brand

    def move(self):
        print(f"{self.brand} car is moving at {self.speed} km/h.")

    def fuel_type(self):
        print("Fuel Type: Petrol")

c1 = Car(130, "Scorpio")

print("Brand:", c1.brand)
print("Speed:", c1.speed, "km/h")

c1.move()
c1.fuel_type()
# Out:
# Brand: Scorpio
# Speed: 130 km/h
# Scorpio car is moving at 130 km/h.
# Fuel Type: Petrol

# %% [markdown]
# #### 25. Class Name: Notification
# #### Problem
# #### Create an abstract class named Notification.
# #### Explanation
# #### Store the recipient name.
# #### __init__(self, recipient)
# #### Create abstract method:
# #### • send(message)
# #### Create subclass:
# #### • EmailNotification
# #### Use super() to initialize the recipient.

# %%
from abc import ABC, abstractmethod

class Notification(ABC):
    def __init__(self, recipient):
        self.recipient = recipient

    @abstractmethod
    def send(self, message):
        pass

class EmailNotification(Notification):
    def __init__(self, recipient, email):
        super().__init__(recipient)
        self.email = email

    def send(self, message):
        print(f"Sending Email to {self.recipient}")
        print(f"Email: {self.email}")
        print(f"Message: {message}")

e1 = EmailNotification("Nikhil", "nikhil@gmail.com")

print("Recipient:", e1.recipient)
print("Email:", e1.email)

e1.send("Your order has been shipped.")
# Out:
# Recipient: Nikhil
# Email: nikhil@gmail.com
# Sending Email to Nikhil
# Email: nikhil@gmail.com
# Message: Your order has been shipped.

# %% [markdown]
# #### 26. Class Name: Shape
# #### Problem
# #### Create an abstract class named Shape.
# #### Explanation
# #### Store the color in the constructor.
# #### Create abstract method:
# #### • area()
# #### Create subclass:
# #### • Rectangle
# #### Use super() to initialize the color and then calculate the area.

# %%
from abc import ABC, abstractmethod

class Shape(ABC):
    def __init__(self, color):
        self.color = color

    @abstractmethod
    def area(self):
        pass

class Rectangle(Shape):
    def __init__(self, color, length, width):
        super().__init__(color)      
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

r = Rectangle("Blue", 10, 5)

print("Color:", r.color)
print("Length:", r.length)
print("Width:", r.width)
print("Area:", r.area())
# Out:
# Color: Blue
# Length: 10
# Width: 5
# Area: 50

# %% [markdown]
# #### 27. Class Name: Employee
# #### Problem
# #### Create an abstract class named Employee.
# #### Explanation
# #### Store:
# #### • Employee name
# #### • Base salary
# #### Create abstract method:
# #### • calculate_bonus()
# #### Create subclass:
# #### • Developer
# #### Use super() to initialize the common employee information before calculating the bonus.

# %%
from abc import ABC, abstractmethod

class Employee(ABC):
    def __init__(self, name, base_salary):
        self.name = name
        self.base_salary = base_salary

    @abstractmethod
    def calculate_bonus(self):
        pass

class Developer(Employee):
    def __init__(self, name, base_salary, programming_language):
        super().__init__(name, base_salary)   
        self.programming_language = programming_language

    def calculate_bonus(self):
        bonus = self.base_salary * 0.15   
        return bonus

d1 = Developer("Yash", 60000, "Python")

print("Employee Name:", d1.name)
print("Base Salary:", d1.base_salary)
print("Programming Language:", d1.programming_language)
print("Bonus:", d1.calculate_bonus())
# Out:
# Employee Name: Yash
# Base Salary: 60000
# Programming Language: Python
# Bonus: 9000.0

# %% [markdown]
# #### 28. Class Name: Vehicle
# ####  Problem
# ####  Create an abstract class named Vehicle.
# ####  Explanation
# ####  Store the vehicle brand.
# ####  Create a multilevel inheritance structure:
# ####  • Vehicle → Car → ElectricCar
# ####  Use super() in each constructor to initialize the parent class data.

# %%
from abc import ABC, abstractmethod

class Vehicle(ABC):
    def __init__(self, brand):
        self.brand = brand

    @abstractmethod
    def start(self):
        pass

class Car(Vehicle):
    def __init__(self, brand, model):
        super().__init__(brand)     
        self.model = model

    def start(self):
        print(f"{self.brand} {self.model} is starting.")

class ElectricCar(Car):
    def __init__(self, brand, model, battery):
        super().__init__(brand, model)    
        self.battery = battery

    def battery_status(self):
        print(f"Battery Capacity: {self.battery} kWh")

e1 = ElectricCar("Tesla", "Model 2", 85)

print("Brand:", e1.brand)
print("Model:", e1.model)
print("Battery:", e1.battery, "kWh")

e1.start()
e1.battery_status()
# Out:
# Brand: Tesla
# Model: Model 2
# Battery: 85 kWh
# Tesla Model 2 is starting.
# Battery Capacity: 85 kWh

# %% [markdown]
# #### 29. Class Name: Calculator
# #### Problem
# #### Create an abstract class named Calculator.
# #### Explanation
# #### Store the calculator name.
# #### __init__(self, name)
# #### Create abstract method:
# #### • compute(a, b)
# #### Create subclass:
# #### • ScientificCalculator
# #### Use super() to initialize the calculator name.

# %%
from abc import ABC, abstractmethod

class Calculator(ABC):
    def __init__(self, name):
        self.name = name

    @abstractmethod
    def compute(self, a, b):
        pass

class ScientificCalculator(Calculator):
    def __init__(self, name):
        super().__init__(name)     

    def compute(self, a, b):
        return a ** b      

sc = ScientificCalculator("Casio Scientific Calculator")

print("Calculator Name:", sc.name)
print("Result:", sc.compute(3, 5))
# Out:
# Calculator Name: Casio Scientific Calculator
# Result: 243
