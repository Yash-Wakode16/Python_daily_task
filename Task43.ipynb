# %% [markdown]
# #### 1. Write a program to find the first non-repeating character.

# %%
from collections import Counter
def first_non_repeating(s):
    count = Counter(s)
    for char in s:
        if count[char] == 1:
            return char
    return None
text = input("Enter a string: ")
result = first_non_repeating(text)
if result:
    print("First non-repeating character:", result)
else:
    print("No non-repeating character found.")
# Out:
# Enter a string:  swiss
# First non-repeating character: w

# %% [markdown]
# #### 2. Write a program to find all duplicate characters in a string.

# %%
text = input("Enter a string: ")
duplicates = []
for char in text:
    if text.count(char) > 1 and char not in duplicates:
        duplicates.append(char)
print("Duplicate characters:", duplicates)
# Out:
# Enter a string:  programming
# Duplicate characters: ['r', 'g', 'm']

# %% [markdown]
# #### 3. Write a program to check whether a string contains only digits.

# %%
text = input("Enter a string: ")
for char in text:
    if not char.isdigit():
        print("Not Only Digits")
        break
    else:
         print("Only Digits")
# Out:
# Enter a string:  123h43
# Only Digits
# Only Digits
# Only Digits
# Not Only Digits

# %% [markdown]
# #### 4. Use map() to convert a list of Celsius temperatures into Fahrenheit.

# %%
celsius = [0, 10, 20, 30, 40]
fahrenheit = list(map(lambda c: (c * 9/5) + 32, celsius))
print("Celsius:", celsius)
print("Fahrenheit:", fahrenheit)
# Out:
# Celsius: [0, 10, 20, 30, 40]
# Fahrenheit: [32.0, 50.0, 68.0, 86.0, 104.0]

# %% [markdown]
# #### 5 Write a program to group students according to their marks/grade using a dictionary.

# %%
students = {
    "Rahul": 85,
    "Priya": 72,
    "Amit": 91,
    "Sneha": 65,
    "Rohan": 48,
    "Neha": 88
}
groups = {
    "A": [],
    "B": [],
    "C": [],
    "D": []
}
for name, marks in students.items():
    if marks >= 80:
        groups["A"].append(name)
    elif marks >= 60:
        groups["B"].append(name)
    elif marks >= 40:
        groups["C"].append(name)
    else:
        groups["D"].append(name)

print(groups)
